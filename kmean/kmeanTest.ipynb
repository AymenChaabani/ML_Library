# %%
from kmean import kmean
import numpy as np

# %%
k=kmean()

# %%
a=np.arange(1,10,0.1)
np.random.seed(1)
np.random.shuffle(a)
a
# Out:
# array([6.8, 8.8, 5.3, 6.5, 9.7, 8.4, 7. , 6.2, 5.6, 4.9, 5. , 4.1, 7.9,
#        3.7, 4.8, 7.8, 2. , 1.2, 9.9, 8. , 6.3, 2.9, 9.4, 4.6, 4.3, 4.2,
#        5.5, 7.6, 7.2, 6.4, 4.5, 5.1, 5.9, 3.3, 4.4, 9.3, 5.4, 6.9, 2.5,
#        8.3, 9.1, 3.6, 9.8, 6.6, 1.4, 5.8, 3.1, 8.7, 1.3, 7.5, 4. , 9.2,
#        5.2, 5.7, 6.1, 7.7, 3.4, 1.8, 2.7, 1. , 9. , 6.7, 3.2, 7.1, 7.3,
#        1.7, 9.6, 2.3, 9.5, 2.4, 3.9, 3.8, 2.1, 2.8, 3. , 6. , 3.5, 1.6,
#        8.1, 8.6, 1.1, 2.6, 7.4, 8.9, 1.5, 8.5, 1.9, 8.2, 2.2, 4.7])

# %%
k.learn(a,3)
k.infer()
# Out:
# {0: [8.800000000000008,
#   9.700000000000008,
#   8.400000000000006,
#   7.900000000000006,
#   7.800000000000006,
#   9.900000000000007,
#   8.000000000000007,
#   9.400000000000007,
#   7.600000000000006,
#   7.2000000000000055,
#   9.300000000000008,
#   8.300000000000006,
#   9.100000000000007,
#   9.800000000000008,
#   8.700000000000006,
#   7.500000000000005,
#   9.200000000000006,
#   7.700000000000006,
#   9.000000000000007,
#   7.100000000000005,
#   7.300000000000006,
#   9.600000000000009,
#   9.500000000000007,
#   8.100000000000007,
#   8.600000000000007,
#   7.400000000000006,
#   8.900000000000007,
#   8.500000000000007,
#   8.200000000000006],
#  1: [4.100000000000003,
#   3.7000000000000024,
#   2.000000000000001,
#   1.2000000000000002,
#   2.9000000000000017,
#   4.3000000000000025,
#   4.200000000000003,
#   3.300000000000002,
#   4.400000000000003,
#   2.5000000000000013,
#   3.6000000000000023,
#   1.4000000000000004,
#   3.100000000000002,
# ...

# %%
np.max(k.infer()[0])
# Out:
# 3.9000000000000026

# %%
np.min(k.infer()[1])
# Out:
# 4.000000000000003
